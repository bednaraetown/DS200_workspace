# %% [markdown]
# <h1><center>DS200 - Lec9: Data Visualization with Matplotlib</center></h1>

# %% [markdown]
# ## Introduction

# %% [markdown]
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. So if you happen to be familiar with matlab, matplotlib will feel natural to you.
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general
#
# Some key terms that you want to know before you jump into it:
#
# ![Anatomy of a figure](https://res.cloudinary.com/practicaldev/image/fetch/s--1x1epD95--/c_limit%2Cf_auto%2Cfl_progressive%2Cq_auto%2Cw_880/https://thepracticaldev.s3.amazonaws.com/i/b9psb0mtz7yk8qmfe26f.png)
#
# Matplotlib allows you to create reproducible figures programmatically. Let's learn how to use it! Before continuing this lecture, I encourage you just to explore the official Matplotlib web page: http://matplotlib.org/
#
# ## Installation
#
# In case you need installation:
#
# ```conda install matplotlib```
#
# or
#
# ```pip install matplotlib```
#
# ## Importing

# %% [markdown]
# Import the `matplotlib.pyplot` module under the name `plt` (the tidy way):

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Section 1. Basic Example
#
# Let's walk through a very simple example using two numpy arrays. You can also use lists, but most likely you'll be passing numpy arrays or pandas columns (which essentially also behave like arrays).

# %% [markdown]
# #### The data we want to plot:

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ### 1) Function-based method
#
# We can create a very simple line plot using the following.

# %% [markdown]
# ### 2) Object Oriented Method
# Now that we've seen the basics, let's break it all down with a more formal introduction of Matplotlib's Object Oriented API. This means we will instantiate figure objects and then call methods or attributes from that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
# To begin we create a figure instance. Then we can add axes to that figure:

# %%
# Creates blank canvas
fig = plt.figure()

# Define the boundaries of Axes1 and Axes2
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger plot on Axes 1
axes1.

axes1.legend() # Will use the label to generate
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 1 Title')

# Insert small plot on Axes 2
axes2.

axes2.legend() # Will use the label to generate
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# Code is a little more complicated, but the advantage is that we now have full control of where the plot axes are placed, and we can easily add more than one axis to the figure.

# %% [markdown]
# ### 3) Using subplots()
#
# The plt.subplots() object will act as a more automatic axis manager.
#
# You can specify the number of rows and columns when creating the subplots() object. It returns a tuple: the figure object, and an array of axes.

# %%
# Empty canvas of 1 by 2 subplots
fig_ex3, axes_ex3 =

# %%
# Axes is an array of axes to plot on
axes_ex3
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# We can iterate through this array:

# %%
# Display the figure object  
fig_ex3

# %% [markdown]
# ### 4) Figure size, aspect ratio and DPI

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the `figsize` and `dpi` keyword arguments.
# * `figsize` is a tuple of the width and height of the figure in inches
# * `dpi` is the dots-per-inch (pixel per inch).
#
# For example:

# %% [markdown]
# The same arguments can also be passed to layout managers, such as the `subplots` function:

# %%
fig_ex4, axes_ex4 = 




axes_ex4.plot(x, y, 'r')
axes_ex4.set_xlabel('x')
axes_ex4.set_ylabel('y')
axes_ex4.set_title('Big figure');

# %% [markdown]
# ### 5) Saving figures
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.

# %% [markdown]
# To save a figure to a file we can use the `savefig` method in the `Figure` class:

# %% [markdown]
# Here we can also optionally specify the DPI and choose between different output formats:

# %%
fig_ex4.savefig("filename.png", dpi=200)

# %% [markdown]
# ## Section 2: Matplotlib Supported Plot Types
#
# There are many specialized plots we can create, such as barplots, histograms, scatter plots, and much more. Most of these type of plots we will actually create using seaborn, a statistical plotting library for Python. But here are a few examples of these type of plots.

# %%
fig, axes = 


# Plot bar graph on axes[0]


axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].set_title('Bar graph')


# Plot histogram on axes[1]


axes[1].set_xlabel('Bins')
axes[1].set_ylabel('y')
axes[1].set_title('Histogram')


fig.tight_layout()

# %% [markdown]
# ## Section 3: Pandas Built-in Visualization
#
# Pandas library in python is mainly used for data analysis. It is not a data visualization library but, we can create basic plots using Pandas. Pandas is highly useful and practical if we want to create exploratory data analysis plots. We do not need to import other data visualization libraries in addition to Pandas for such tasks.

# %% [markdown]
# #### Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# #### Read the given dataset into a Pandas DataFrames type. Name the DataFrames as `data`

# %%
data_url = 'https://raw.githubusercontent.com/BlueJayADAL/CS121/master/datasets/iris.csv'

# %%
data = pd.read_csv(data_url, 
                   header = None, 
                   names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'])

# %% [markdown]
# ### 1) Line Plot and Area Plot
#
# #### Show a line graph of all the variables in the DataFrame

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Show a line graph with only `sepal_length` and `sepal_width` variables from the DataFrame

# %%
# Out:
# <AxesSubplot:title={'center':'Line graph of sepal length and width'}, xlabel='Flower instances', ylabel='Measurement in cm'>

# %% [markdown]
# #### Show an area graph of all the variables in the DataFrame

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 2) Bar Plot
#
# #### Create a bar graph with `sepal_length` for all data entries. Enlarge the graph to show details.

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Exercise: Plot a bar graph with the average `sepal_length` for each flower `species` type

# %%
# Out:
# <AxesSubplot:title={'center':'Average sepal length for each species'}, xlabel='species', ylabel='Measurement in cm'>

# %% [markdown]
# ### 3) Histogram

# %% [markdown]
# #### Display a histogram of `sepal_length` with all data entries.

# %%
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Display histograms of all four variables in subplots

# %%
# Split these four histograms into their own subplot
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# ### 4) Scatter Plot
# #### Show a simple scatterplot with two variables `sepal_length` and `sepal_width`.

# %%
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ### 5) Pie Plot
#
# #### Calculate the total number of flowers for each species. Then generate a pie chart with the numbers.

# %%
# Out:
# <AxesSubplot:ylabel='species'>

# %% [markdown]
# ## Further reading

# %% [markdown]
# * http://www.matplotlib.org - The project web page for matplotlib.
# * https://github.com/matplotlib/matplotlib - The source code for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.
